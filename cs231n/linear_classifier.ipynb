# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from cs231nlib.utils import *
from nn import NearestNeighbor

# %%
Xtr, Ytr, Xte, Yte = load_CIFAR10("datasets/cifar-10-batches-py/")

# %%
visualize_CIFAR(Xtr, Ytr, 5)

# %%
print Xtr.shape
# Out:
# (50000, 32, 32, 3)

# %%
# flatten out images
Xtr_flat = Xtr.reshape(Xtr.shape[0], 32*32*3)
Xte_flat = Xte.reshape(Xte.shape[0], 32*32*3)

# %%
nn = NearestNeighbor()
nn.train(Xtr_flat, Ytr)

# %%
Yte_predict = nn.predict(Xte_flat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-28c63391601b> in <module>()
# ----> 1 Yte_predict = nn.predict(Xte_flat)
#
# /home/swair/ml/course/cs231n/nn.pyc in predict(self, Xtst)
#      14         for i in xrange(n_test):
#      15             # L1 distances
# ---> 16             distances = np.sum(np.abs(self.Xtr - Xtst[i,:]), axis = 1)
#      17             min_index = np.argmin(distances)
#      18             ypred[i] = self.ytr[min_index]
#
# KeyboardInterrupt:

# %%
print 'accuracy: %f' % ( np.mean(Yte_predict == Yte) )
